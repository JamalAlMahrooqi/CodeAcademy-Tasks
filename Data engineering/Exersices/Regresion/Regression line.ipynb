# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
gold=pd.read_csv("gold-prices.csv")
movie=pd.read_csv("movie_dataset.csv")
oil=pd.read_csv("oil.csv")

# %%
movie
# Out:
#       index     budget                                    genres  \
# 0         0  237000000  Action Adventure Fantasy Science Fiction
# 1         1  300000000                  Adventure Fantasy Action
# 2         2  245000000                    Action Adventure Crime
# 3         3  250000000               Action Crime Drama Thriller
# 4         4  260000000          Action Adventure Science Fiction
# ...     ...        ...                                       ...
# 4798   4798     220000                     Action Crime Thriller
# 4799   4799       9000                            Comedy Romance
# 4800   4800          0             Comedy Drama Romance TV Movie
# 4801   4801          0                                       NaN
# 4802   4802          0                               Documentary
#
#                                                homepage      id  \
# 0                           http://www.avatarmovie.com/   19995
# ...

# %%
data=movie.corr()
sns.heatmap(data,annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
movie_data=movie[['budget','revenue']]
movie_data
# Out:
#          budget     revenue
# 0     237000000  2787965087
# 1     300000000   961000000
# 2     245000000   880674609
# 3     250000000  1084939099
# 4     260000000   284139100
# ...         ...         ...
# 4798     220000     2040920
# 4799       9000           0
# 4800          0           0
# 4801          0           0
# 4802          0           0
#
# [4803 rows x 2 columns]

# %%
x=movie_data['budget']
y=movie_data['revenue']
plt.scatter(x,y)

# %%
l_model=sns.lmplot(x='budget', y='revenue', data=movie,order=1,ci=80,height=7, aspect=2 ,
          scatter_kws={"marker":"o","color":"indianred"});

# %%
sns.residplot(data=movie,x='budget',y='revenue',lowess=True, line_kws=dict(color="r"))
sns.set(rc={'figure.figsize':(110.70,100)})

# %%
data=oil.corr()
sns.heatmap(data,annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
x=oil['Value']
y=gold['Year']
plt.scatter(y,x)

# %%
gold["Date"]=pd.to_datetime(gold["Date"])
gold['Year'] = pd.DatetimeIndex(gold['Date']).year
gold['Month'] = pd.DatetimeIndex(gold['Date']).month
gold=gold[['Date', 'Year', 'Month','Price']]
gold
# Out:
#           Date  Year  Month    Price
# 0   1988-05-01  1988      5   451.32
# 1   1988-06-01  1988      6   451.66
# 2   1988-07-01  1988      7   437.45
# 3   1988-10-01  1988     10   406.39
# 4   1988-11-01  1988     11   419.97
# ..         ...   ...    ...      ...
# 379 2019-02-01  2019      2  1319.76
# 380 2019-03-01  2019      3  1302.29
# 381 2019-07-01  2019      7  1414.61
# 382 2019-08-01  2019      8  1497.10
# 383 2019-11-01  2019     11  1471.92
#
# [384 rows x 4 columns]

# %%
x=gold['Price']
y=gold['Year']
plt.scatter(y,x)

# %%
data=gold.corr()
sns.heatmap(data,annot=True, cmap="Blues")
# Out:
# <AxesSubplot:>

# %%
l_model=sns.lmplot(x='Price', y='Year', data=gold,order=1,ci=90,
          scatter_kws={"marker":"o","color":"indianred"});

# %%
sns.residplot(data=gold,x='Price',y='Year',lowess=True, line_kws=dict(color="r"));
